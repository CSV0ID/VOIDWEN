# %% [markdown]
# # 02 - Training (Colab, free T4)
#
# Fine-tune opus-mt-zh-en on the wenyan corpus. Checkpoints go to Google Drive so
# training resumes across the 12h session limit. Runs 1-3 = epochs 1-3.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/CSV0ID/voidwen.git
# %cd voidwen
# !pip install -q -r model/requirements.txt

# %%
# --resume picks up the latest checkpoint in output_dir; safe to re-run each session.
# !python model/train.py \
  --output_dir /content/drive/MyDrive/voidwen/ckpt \
  --epochs 3 --batch_size 32 --resume
